# %%
import pandas as pd
import os

# %% [markdown]
# Reading a CSV file

# %%
pwd = os.getcwd() #creates a string of the fodler this python script is stored in
pwd
# Out:
# 'c:\\Users\\User\\Desktop\\pythonWork\\PythonTutorial'

# %%
filepath = pwd + "/simple_csv.csv" #creates a string that is the filepath to the simple_csv file
#filepath

# %%
first_import = pd.read_csv(filepath, nrows=10)
first_import
# Out:
#     Column1   Column2   Column3
# 0  0.280925  0.910368  0.692982
# 1  0.719882  0.210024  0.761276
# 2  0.235752  0.059796  0.154667
# 3  0.603366  0.485614  0.013345
# 4  0.039985  0.236359  0.811832
# 5  0.015478  0.543641  0.112719
# 6  0.192540  0.409874  0.875082
# 7  0.380921  0.045468  0.515859
# 8  0.592471  0.786421  0.047249
# 9  0.072112  0.695694  0.409573

# %%
series_test = list(range(1,100))
pd.Series(series_test) #creates a pandas series

#left column is key and right column is the value
# Out:
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
#       ..
# 94    95
# 95    96
# 96    97
# 97    98
# 98    99
# Length: 99, dtype: int64

# %%
pwd = os.getcwd() #creates a string of the fodler this python script is stored in

filepath = pwd + "/simple_csv.csv" #creates a string that is the filepath to the simple_csv file

first_import = pd.read_csv(filepath)
first_import
# Out:
#      Column1   Column2   Column3
# 0   0.280925  0.910368  0.692982
# 1   0.719882  0.210024  0.761276
# 2   0.235752  0.059796  0.154667
# 3   0.603366  0.485614  0.013345
# 4   0.039985  0.236359  0.811832
# 5   0.015478  0.543641  0.112719
# 6   0.192540  0.409874  0.875082
# 7   0.380921  0.045468  0.515859
# 8   0.592471  0.786421  0.047249
# 9   0.072112  0.695694  0.409573
# 10  0.898072  0.070956  0.209020
# 11  0.722038  0.211985  0.324164
# 12  0.513517  0.091548  0.664279
# 13  0.436729  0.040322  0.548167
# 14  0.864039  0.963556  0.106398
# 15  0.724761  0.410422  0.587589
# 16  0.198926  0.245207  0.767356
# 17  0.748500  0.019264  0.046678
# 18  0.920639  0.212611  0.520463
# 19  0.452024  0.123660  0.847451
# 20  0.542977  0.265852  0.410926
# 21  0.355266  0.860616  0.589431
# 22  0.142688  0.406456  0.204095
# 23  0.850436  0.129426  0.719027
# 24  0.443476  0.388967  0.596924
# 25  0.467100  0.416908  0.098037
# 26  0.338536  0.935814  0.736899
# ...

# %% [markdown]
# Reading an Excel file

# %% [markdown]
# excel_import = pd.read_excel(filepath, sheet_name="Sheet1") # this lets you read a certain sheet from an excel file

# %% [markdown]
# Columns

# %%
first_import.Column1
first_import["Column1"]
# Out:
# 0     0.280925
# 1     0.719882
# 2     0.235752
# 3     0.603366
# 4     0.039985
# 5     0.015478
# 6     0.192540
# 7     0.380921
# 8     0.592471
# 9     0.072112
# 10    0.898072
# 11    0.722038
# 12    0.513517
# 13    0.436729
# 14    0.864039
# 15    0.724761
# 16    0.198926
# 17    0.748500
# 18    0.920639
# 19    0.452024
# 20    0.542977
# 21    0.355266
# 22    0.142688
# 23    0.850436
# 24    0.443476
# 25    0.467100
# 26    0.338536
# 27    0.942101
# 28    0.570130
# Name: Column1, dtype: float64

# %%
first_import["Column1"]
# Out:
# 0     0.280925
# 1     0.719882
# 2     0.235752
# 3     0.603366
# 4     0.039985
# 5     0.015478
# 6     0.192540
# 7     0.380921
# 8     0.592471
# 9     0.072112
# 10    0.898072
# 11    0.722038
# 12    0.513517
# 13    0.436729
# 14    0.864039
# 15    0.724761
# 16    0.198926
# 17    0.748500
# 18    0.920639
# 19    0.452024
# 20    0.542977
# 21    0.355266
# 22    0.142688
# 23    0.850436
# 24    0.443476
# 25    0.467100
# 26    0.338536
# 27    0.942101
# 28    0.570130
# Name: Column1, dtype: float64

# %%
first_import["New Column"] = 1  #adds a new column
first_import["New Column 2"] = list(range(29))
first_import["Added Output"] = first_import["New Column"] + first_import["New Column 2"]  #combine columns

first_import
# Out:
#      Column1   Column2   Column3  New Column  New Column 2  Added Output
# 0   0.280925  0.910368  0.692982           1             0             1
# 1   0.719882  0.210024  0.761276           1             1             2
# 2   0.235752  0.059796  0.154667           1             2             3
# 3   0.603366  0.485614  0.013345           1             3             4
# 4   0.039985  0.236359  0.811832           1             4             5
# 5   0.015478  0.543641  0.112719           1             5             6
# 6   0.192540  0.409874  0.875082           1             6             7
# 7   0.380921  0.045468  0.515859           1             7             8
# 8   0.592471  0.786421  0.047249           1             8             9
# 9   0.072112  0.695694  0.409573           1             9            10
# 10  0.898072  0.070956  0.209020           1            10            11
# 11  0.722038  0.211985  0.324164           1            11            12
# ...

# %%
first_import
# Out:
#      Column1   Column2   Column3  New Column  New Column 2  Added Output
# 0   0.280925  0.910368  0.692982           1             0             1
# 1   0.719882  0.210024  0.761276           1             1             2
# 2   0.235752  0.059796  0.154667           1             2             3
# 3   0.603366  0.485614  0.013345           1             3             4
# 4   0.039985  0.236359  0.811832           1             4             5
# 5   0.015478  0.543641  0.112719           1             5             6
# 6   0.192540  0.409874  0.875082           1             6             7
# 7   0.380921  0.045468  0.515859           1             7             8
# 8   0.592471  0.786421  0.047249           1             8             9
# 9   0.072112  0.695694  0.409573           1             9            10
# 10  0.898072  0.070956  0.209020           1            10            11
# 11  0.722038  0.211985  0.324164           1            11            12
# ...

# %%
#drop column
first_import.drop(columns="New Column", inplace=True, errors='ignore')

first_import
# Out:
#      Column1   Column2   Column3  New Column 2  Added Output
# 0   0.280925  0.910368  0.692982             0             1
# 1   0.719882  0.210024  0.761276             1             2
# 2   0.235752  0.059796  0.154667             2             3
# 3   0.603366  0.485614  0.013345             3             4
# 4   0.039985  0.236359  0.811832             4             5
# 5   0.015478  0.543641  0.112719             5             6
# 6   0.192540  0.409874  0.875082             6             7
# 7   0.380921  0.045468  0.515859             7             8
# 8   0.592471  0.786421  0.047249             8             9
# 9   0.072112  0.695694  0.409573             9            10
# 10  0.898072  0.070956  0.209020            10            11
# 11  0.722038  0.211985  0.324164            11            12
# 12  0.513517  0.091548  0.664279            12            13
# 13  0.436729  0.040322  0.548167            13            14
# ...

# %% [markdown]
# ### Dropping Rows

# %%
# loc allows for the use of column names
#iloc is based off numerical indexing 

first_import.loc[:, "Column1"] #selects all rows in said column

first_import.loc[0:4, "Column1"] #Selects a range of rows in said column

#first_import.loc[:, 0:2] #selects all rows in column 1 and 2
# Out:
# 0    0.280925
# 1    0.719882
# 2    0.235752
# 3    0.603366
# 4    0.039985
# Name: Column1, dtype: float64
